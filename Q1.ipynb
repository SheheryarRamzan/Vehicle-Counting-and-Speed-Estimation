# %%
import cv2
import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk

class VideoCroppingApp:
    def __init__(self, root, video_path):
        self.root = root
        self.video_path = video_path

        self.cap = cv2.VideoCapture(video_path)
        self.width = int(self.cap.get(3))
        self.height = int(self.cap.get(4))

        self.canvas = tk.Canvas(root, width=self.width, height=self.height)
        self.canvas.pack()

        self.rect_id = None
        self.start_x = None
        self.start_y = None

        self.canvas.bind("<ButtonPress-1>", self.on_press)
        self.canvas.bind("<B1-Motion>", self.on_drag)
        self.canvas.bind("<ButtonRelease-1>", self.on_release)

        self.root.protocol("WM_DELETE_WINDOW", self.on_close)

        self.update_preview()

    def update_preview(self):
        ret, frame = self.cap.read()

        if ret:
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            img = Image.fromarray(frame)
            img_tk = ImageTk.PhotoImage(img)
            self.canvas.img_tk = img_tk  # Keep a reference to avoid garbage collection
            self.canvas.create_image(0, 0, anchor=tk.NW, image=img_tk)
            self.root.after(10, self.update_preview)
        else:
            self.cap.release()

    def on_press(self, event):
        self.start_x = self.canvas.canvasx(event.x)
        self.start_y = self.canvas.canvasy(event.y)

        if self.rect_id:
            self.canvas.delete(self.rect_id)

        # Draw the video frame
        ret, frame = self.cap.read()
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        img = Image.fromarray(frame)
        img_tk = ImageTk.PhotoImage(img)
        self.canvas.img_tk = img_tk
        self.canvas.create_image(0, 0, anchor=tk.NW, image=img_tk)

        # Draw the red selection box on the video frame
        self.rect_id = self.canvas.create_rectangle(
            self.start_x, self.start_y, self.start_x, self.start_y, outline="red"
        )
        self.canvas.tag_raise(self.rect_id)  # Ensure the red box is on top

    def on_drag(self, event):
        cur_x = self.canvas.canvasx(event.x)
        cur_y = self.canvas.canvasy(event.y)

        self.canvas.coords(self.rect_id, self.start_x, self.start_y, cur_x, cur_y)
        self.canvas.tag_raise(self.rect_id)  # Raise the red box during dragging
        self.root.update()  # Update the Tkinter main loop during dragging


    def on_release(self, event):
        end_x = self.canvas.canvasx(event.x)
        end_y = self.canvas.canvasy(event.y)

        self.crop_video(int(self.start_x), int(self.start_y), int(end_x), int(end_y))

    def crop_video(self, x1, y1, x2, y2):
        self.cap.set(1, 0)  # Set video to the beginning
        fourcc = cv2.VideoWriter_fourcc(*"mp4v")
        out = cv2.VideoWriter("cropped_video.mp4", fourcc, 30.0, (x2 - x1, y2 - y1))

        while True:
            ret, frame = self.cap.read()

            if not ret:
                break

            cropped_frame = frame[y1:y2, x1:x2]
            out.write(cropped_frame)

            cv2.imshow("Cropped Video", cropped_frame)

            if cv2.waitKey(1) & 0xFF == ord("q"):
                break

        self.cap.release()
        out.release()
        cv2.destroyAllWindows()

    def on_close(self):
        self.cap.release()
        self.root.destroy()

def main():
    root = tk.Tk()
    root.title("Video Cropping App")

    file_path = filedialog.askopenfilename(title="Select a video file", filetypes=[("Video files", "*.mp4;*.avi")])

    if file_path:
        app = VideoCroppingApp(root, file_path)
        root.mainloop()

if __name__ == "__main__":
    main()

# %%
import os
from ultralytics import YOLO
os.environ['KMP_DUPLICATE_LIB_OK']='True'


model = YOLO('yolov8n.pt')

# Open the video file
video_path = "cropped_video.mp4"
frameCount = -1
# Create a directory to store the keypoints files
output_directory = "detections"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()
    frameCount = frameCount + 1

    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True)
        keypoints_path = os.path.join(output_directory, f"frame{frameCount}.txt")
        with open(keypoints_path, 'w') as file:
            for r in results:
                keypoint_JSON = r.tojson(normalize=True)
                file.write(keypoint_JSON)
                file.write('\n')
        # Visualize the results on the frame
        annotated_frame = results[0].plot()
        # save it in an image
        cv2.imwrite("frame.jpg",annotated_frame)

        # Display the annotated frame
        cv2.imshow("YOLOv8 Tracking", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 7 cars, 1 motorcycle, 278.4ms
# Speed: 11.9ms preprocess, 278.4ms inference, 19.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 motorcycle, 212.0ms
# Speed: 0.0ms preprocess, 212.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 motorcycle, 180.3ms
# Speed: 6.2ms preprocess, 180.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 188.6ms
# Speed: 0.0ms preprocess, 188.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 171.6ms
# Speed: 6.4ms preprocess, 171.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 193.6ms
# Speed: 8.9ms preprocess, 193.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 208.7ms
# Speed: 0.0ms preprocess, 208.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 192.4ms
# Speed: 5.9ms preprocess, 192.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 224.4ms
# Speed: 0.0ms preprocess, 224.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 234.1ms
# Speed: 6.6ms preprocess, 234.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 280.1ms
# Speed: 0.0ms preprocess, 280.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 262.7ms
# Speed: 3.5ms preprocess, 262.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 233.4ms
# Speed: 8.0ms preprocess, 233.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 241.6ms
# Speed: 8.0ms preprocess, 241.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 212.2ms
# Speed: 3.6ms preprocess, 212.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 197.9ms
# Speed: 3.9ms preprocess, 197.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 177.2ms
# Speed: 5.5ms preprocess, 177.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 191.3ms
# Speed: 4.0ms preprocess, 191.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 213.4ms
# Speed: 0.0ms preprocess, 213.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 195.4ms
# Speed: 1.1ms preprocess, 195.4ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 193.3ms
# Speed: 6.9ms preprocess, 193.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 185.3ms
# Speed: 0.0ms preprocess, 185.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 214.0ms
# Speed: 2.8ms preprocess, 214.0ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 205.8ms
# Speed: 4.9ms preprocess, 205.8ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 232.6ms
# Speed: 4.5ms preprocess, 232.6ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 211.0ms
# Speed: 7.2ms preprocess, 211.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 219.6ms
# Speed: 0.0ms preprocess, 219.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 243.3ms
# Speed: 0.0ms preprocess, 243.3ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 195.4ms
# Speed: 3.4ms preprocess, 195.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 207.9ms
# Speed: 4.8ms preprocess, 207.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 205.5ms
# Speed: 2.3ms preprocess, 205.5ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 245.1ms
# Speed: 8.0ms preprocess, 245.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 244.3ms
# Speed: 5.0ms preprocess, 244.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 252.5ms
# Speed: 4.6ms preprocess, 252.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 263.3ms
# Speed: 6.9ms preprocess, 263.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 248.6ms
# Speed: 4.4ms preprocess, 248.6ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 228.9ms
# Speed: 5.0ms preprocess, 228.9ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 262.2ms
# Speed: 4.9ms preprocess, 262.2ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 246.0ms
# Speed: 0.0ms preprocess, 246.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 247.9ms
# Speed: 2.1ms preprocess, 247.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 237.4ms
# Speed: 0.0ms preprocess, 237.4ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 249.0ms
# Speed: 0.0ms preprocess, 249.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 238.7ms
# Speed: 3.4ms preprocess, 238.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 204.3ms
# Speed: 7.6ms preprocess, 204.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 215.6ms
# Speed: 2.9ms preprocess, 215.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 240.2ms
# Speed: 5.6ms preprocess, 240.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 207.1ms
# Speed: 3.7ms preprocess, 207.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 255.7ms
# Speed: 4.8ms preprocess, 255.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 248.0ms
# Speed: 0.0ms preprocess, 248.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 228.4ms
# Speed: 6.0ms preprocess, 228.4ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 226.5ms
# Speed: 4.0ms preprocess, 226.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 209.8ms
# Speed: 0.0ms preprocess, 209.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 255.7ms
# Speed: 1.9ms preprocess, 255.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 217.3ms
# Speed: 7.1ms preprocess, 217.3ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 motorcycle, 230.2ms
# Speed: 8.5ms preprocess, 230.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 motorcycle, 280.5ms
# Speed: 4.3ms preprocess, 280.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 motorcycle, 226.7ms
# Speed: 7.4ms preprocess, 226.7ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 motorcycle, 238.4ms
# Speed: 2.4ms preprocess, 238.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 motorcycle, 210.7ms
# Speed: 1.2ms preprocess, 210.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 motorcycle, 197.2ms
# Speed: 5.3ms preprocess, 197.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 motorcycle, 231.1ms
# Speed: 4.5ms preprocess, 231.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 motorcycle, 207.7ms
# Speed: 4.5ms preprocess, 207.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 209.9ms
# Speed: 6.7ms preprocess, 209.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 217.5ms
# Speed: 5.3ms preprocess, 217.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 226.7ms
# Speed: 2.3ms preprocess, 226.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 216.1ms
# Speed: 0.0ms preprocess, 216.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 187.6ms
# Speed: 0.0ms preprocess, 187.6ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 194.7ms
# Speed: 4.0ms preprocess, 194.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 motorcycles, 195.8ms
# Speed: 4.6ms preprocess, 195.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 motorcycles, 203.7ms
# Speed: 2.6ms preprocess, 203.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 191.1ms
# Speed: 1.7ms preprocess, 191.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 208.6ms
# Speed: 8.6ms preprocess, 208.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 209.6ms
# Speed: 3.6ms preprocess, 209.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 209.9ms
# Speed: 0.0ms preprocess, 209.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 212.3ms
# Speed: 0.0ms preprocess, 212.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 202.0ms
# Speed: 6.7ms preprocess, 202.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 199.3ms
# Speed: 4.5ms preprocess, 199.3ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 212.2ms
# Speed: 4.5ms preprocess, 212.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 234.3ms
# Speed: 4.0ms preprocess, 234.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 205.3ms
# Speed: 0.0ms preprocess, 205.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 221.4ms
# Speed: 5.0ms preprocess, 221.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 212.2ms
# Speed: 0.0ms preprocess, 212.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 225.6ms
# Speed: 0.0ms preprocess, 225.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 215.5ms
# Speed: 0.0ms preprocess, 215.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 228.0ms
# Speed: 0.0ms preprocess, 228.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 214.8ms
# Speed: 0.0ms preprocess, 214.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 211.1ms
# Speed: 4.8ms preprocess, 211.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 205.2ms
# Speed: 5.7ms preprocess, 205.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 211.5ms
# Speed: 6.2ms preprocess, 211.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 203.3ms
# Speed: 0.0ms preprocess, 203.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 181.7ms
# Speed: 2.1ms preprocess, 181.7ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 199.7ms
# Speed: 0.0ms preprocess, 199.7ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 226.0ms
# Speed: 0.0ms preprocess, 226.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 230.6ms
# Speed: 4.5ms preprocess, 230.6ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 226.9ms
# Speed: 0.0ms preprocess, 226.9ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 245.8ms
# Speed: 8.4ms preprocess, 245.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 208.3ms
# Speed: 0.0ms preprocess, 208.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 218.6ms
# Speed: 0.0ms preprocess, 218.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 217.6ms
# Speed: 1.1ms preprocess, 217.6ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 206.6ms
# Speed: 8.0ms preprocess, 206.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 263.5ms
# Speed: 4.5ms preprocess, 263.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 215.7ms
# Speed: 5.1ms preprocess, 215.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 229.9ms
# Speed: 3.4ms preprocess, 229.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 187.6ms
# Speed: 0.0ms preprocess, 187.6ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 233.4ms
# Speed: 5.1ms preprocess, 233.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 222.0ms
# Speed: 0.0ms preprocess, 222.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 217.7ms
# Speed: 7.0ms preprocess, 217.7ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 217.9ms
# Speed: 4.2ms preprocess, 217.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 175.6ms
# Speed: 6.5ms preprocess, 175.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 217.8ms
# Speed: 4.6ms preprocess, 217.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 199.8ms
# Speed: 0.0ms preprocess, 199.8ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 240.1ms
# Speed: 0.0ms preprocess, 240.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 197.0ms
# Speed: 4.8ms preprocess, 197.0ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 233.4ms
# Speed: 6.6ms preprocess, 233.4ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 233.3ms
# Speed: 4.1ms preprocess, 233.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 226.7ms
# Speed: 8.1ms preprocess, 226.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 226.6ms
# Speed: 0.0ms preprocess, 226.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 238.4ms
# Speed: 2.3ms preprocess, 238.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 257.7ms
# Speed: 1.5ms preprocess, 257.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 214.5ms
# Speed: 5.0ms preprocess, 214.5ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 216.2ms
# Speed: 8.0ms preprocess, 216.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 232.0ms
# Speed: 4.5ms preprocess, 232.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 240.4ms
# Speed: 3.8ms preprocess, 240.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 260.8ms
# Speed: 7.2ms preprocess, 260.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 206.0ms
# Speed: 6.6ms preprocess, 206.0ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 245.2ms
# Speed: 4.0ms preprocess, 245.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 220.5ms
# Speed: 4.7ms preprocess, 220.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 218.1ms
# Speed: 3.1ms preprocess, 218.1ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 220.4ms
# Speed: 3.8ms preprocess, 220.4ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 215.8ms
# Speed: 4.9ms preprocess, 215.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 222.2ms
# Speed: 8.1ms preprocess, 222.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 204.7ms
# Speed: 5.7ms preprocess, 204.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 201.3ms
# Speed: 4.8ms preprocess, 201.3ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 215.6ms
# Speed: 0.0ms preprocess, 215.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 220.9ms
# Speed: 6.4ms preprocess, 220.9ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 224.0ms
# Speed: 4.0ms preprocess, 224.0ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 243.7ms
# Speed: 0.0ms preprocess, 243.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 246.5ms
# Speed: 5.6ms preprocess, 246.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 266.6ms
# Speed: 0.0ms preprocess, 266.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 235.6ms
# Speed: 0.0ms preprocess, 235.6ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 232.8ms
# Speed: 0.0ms preprocess, 232.8ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 261.2ms
# Speed: 0.0ms preprocess, 261.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 252.2ms
# Speed: 7.1ms preprocess, 252.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 260.5ms
# Speed: 4.6ms preprocess, 260.5ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 251.4ms
# Speed: 0.0ms preprocess, 251.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 287.8ms
# Speed: 4.0ms preprocess, 287.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 241.7ms
# Speed: 7.0ms preprocess, 241.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 223.2ms
# Speed: 8.4ms preprocess, 223.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 239.7ms
# Speed: 5.9ms preprocess, 239.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 243.9ms
# Speed: 3.4ms preprocess, 243.9ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 247.8ms
# Speed: 2.5ms preprocess, 247.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 284.2ms
# Speed: 6.4ms preprocess, 284.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 230.6ms
# Speed: 8.0ms preprocess, 230.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 248.0ms
# Speed: 9.6ms preprocess, 248.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 256.0ms
# Speed: 4.5ms preprocess, 256.0ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 220.6ms
# Speed: 5.0ms preprocess, 220.6ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 222.7ms
# Speed: 5.2ms preprocess, 222.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 201.2ms
# Speed: 0.0ms preprocess, 201.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 266.7ms
# Speed: 7.0ms preprocess, 266.7ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 190.4ms
# Speed: 3.7ms preprocess, 190.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 225.6ms
# Speed: 6.5ms preprocess, 225.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 261.2ms
# Speed: 5.5ms preprocess, 261.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 232.4ms
# Speed: 8.9ms preprocess, 232.4ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 220.5ms
# Speed: 6.0ms preprocess, 220.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 192.3ms
# Speed: 6.2ms preprocess, 192.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 240.5ms
# Speed: 2.0ms preprocess, 240.5ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 175.8ms
# Speed: 3.1ms preprocess, 175.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 193.7ms
# Speed: 3.5ms preprocess, 193.7ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 221.0ms
# Speed: 5.2ms preprocess, 221.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 motorcycle, 207.1ms
# Speed: 4.1ms preprocess, 207.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 195.8ms
# Speed: 1.6ms preprocess, 195.8ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 195.7ms
# Speed: 5.9ms preprocess, 195.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 243.3ms
# Speed: 2.5ms preprocess, 243.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 224.6ms
# Speed: 6.9ms preprocess, 224.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 242.3ms
# Speed: 5.2ms preprocess, 242.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 257.4ms
# Speed: 3.1ms preprocess, 257.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 234.2ms
# Speed: 5.3ms preprocess, 234.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 258.3ms
# Speed: 8.5ms preprocess, 258.3ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 239.0ms
# Speed: 5.3ms preprocess, 239.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 210.0ms
# Speed: 5.6ms preprocess, 210.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 truck, 187.8ms
# Speed: 0.0ms preprocess, 187.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 motorcycle, 1 truck, 178.5ms
# Speed: 2.5ms preprocess, 178.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 171.6ms
# Speed: 5.0ms preprocess, 171.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 201.5ms
# Speed: 7.6ms preprocess, 201.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 233.4ms
# Speed: 3.6ms preprocess, 233.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 170.2ms
# Speed: 6.0ms preprocess, 170.2ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 182.7ms
# Speed: 3.6ms preprocess, 182.7ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 214.6ms
# Speed: 10.0ms preprocess, 214.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 241.0ms
# Speed: 5.9ms preprocess, 241.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 185.8ms
# Speed: 4.3ms preprocess, 185.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 213.6ms
# Speed: 0.0ms preprocess, 213.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 230.1ms
# Speed: 0.0ms preprocess, 230.1ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 219.0ms
# Speed: 4.6ms preprocess, 219.0ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 211.7ms
# Speed: 0.0ms preprocess, 211.7ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 230.7ms
# Speed: 0.0ms preprocess, 230.7ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 250.8ms
# Speed: 5.5ms preprocess, 250.8ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 224.1ms
# Speed: 4.1ms preprocess, 224.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 213.8ms
# Speed: 4.2ms preprocess, 213.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 232.0ms
# Speed: 6.0ms preprocess, 232.0ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 1 truck, 217.4ms
# Speed: 0.0ms preprocess, 217.4ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 1 truck, 218.4ms
# Speed: 5.0ms preprocess, 218.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 1 truck, 188.9ms
# Speed: 4.7ms preprocess, 188.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 1 truck, 207.5ms
# Speed: 3.8ms preprocess, 207.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 1 truck, 278.8ms
# Speed: 5.2ms preprocess, 278.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 1 truck, 248.0ms
# Speed: 0.0ms preprocess, 248.0ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 1 truck, 255.2ms
# Speed: 0.0ms preprocess, 255.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 1 motorcycle, 226.4ms
# Speed: 4.8ms preprocess, 226.4ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 1 truck, 268.3ms
# Speed: 5.9ms preprocess, 268.3ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 2 trucks, 248.0ms
# Speed: 1.9ms preprocess, 248.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 1 truck, 266.9ms
# Speed: 2.0ms preprocess, 266.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 truck, 223.8ms
# Speed: 3.3ms preprocess, 223.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 truck, 207.2ms
# Speed: 0.0ms preprocess, 207.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 truck, 215.7ms
# Speed: 0.0ms preprocess, 215.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 truck, 206.4ms
# Speed: 0.0ms preprocess, 206.4ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 218.0ms
# Speed: 0.0ms preprocess, 218.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 200.4ms
# Speed: 4.0ms preprocess, 200.4ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 bus, 207.4ms
# Speed: 5.1ms preprocess, 207.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 209.8ms
# Speed: 0.0ms preprocess, 209.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 207.1ms
# Speed: 0.0ms preprocess, 207.1ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 213.3ms
# Speed: 1.9ms preprocess, 213.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 187.7ms
# Speed: 0.0ms preprocess, 187.7ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 236.7ms
# Speed: 3.5ms preprocess, 236.7ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 243.7ms
# Speed: 5.0ms preprocess, 243.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 246.1ms
# Speed: 0.0ms preprocess, 246.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 211.3ms
# Speed: 0.0ms preprocess, 211.3ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 212.4ms
# Speed: 0.0ms preprocess, 212.4ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 205.6ms
# Speed: 0.0ms preprocess, 205.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 206.9ms
# Speed: 0.0ms preprocess, 206.9ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 224.4ms
# Speed: 3.8ms preprocess, 224.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 226.9ms
# Speed: 0.0ms preprocess, 226.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 200.6ms
# Speed: 0.0ms preprocess, 200.6ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 202.0ms
# Speed: 5.0ms preprocess, 202.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 truck, 212.6ms
# Speed: 0.0ms preprocess, 212.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 2 trucks, 246.8ms
# Speed: 0.0ms preprocess, 246.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 2 trucks, 236.8ms
# Speed: 6.6ms preprocess, 236.8ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 truck, 213.9ms
# Speed: 0.0ms preprocess, 213.9ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 truck, 194.7ms
# Speed: 3.2ms preprocess, 194.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 truck, 242.8ms
# Speed: 1.4ms preprocess, 242.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 2 trucks, 199.0ms
# Speed: 4.8ms preprocess, 199.0ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 motorcycle, 1 truck, 202.4ms
# Speed: 5.3ms preprocess, 202.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 motorcycle, 1 truck, 180.3ms
# Speed: 0.0ms preprocess, 180.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 motorcycle, 1 truck, 212.5ms
# Speed: 0.0ms preprocess, 212.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 motorcycle, 1 truck, 244.0ms
# Speed: 4.5ms preprocess, 244.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 225.1ms
# Speed: 5.1ms preprocess, 225.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 239.0ms
# Speed: 5.1ms preprocess, 239.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 238.8ms
# Speed: 4.2ms preprocess, 238.8ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 237.3ms
# Speed: 5.5ms preprocess, 237.3ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 2 trucks, 250.9ms
# Speed: 5.9ms preprocess, 250.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 244.0ms
# Speed: 0.0ms preprocess, 244.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 2 trucks, 224.0ms
# Speed: 4.5ms preprocess, 224.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 223.3ms
# Speed: 0.0ms preprocess, 223.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 229.8ms
# Speed: 6.2ms preprocess, 229.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 208.6ms
# Speed: 5.7ms preprocess, 208.6ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 182.8ms
# Speed: 4.2ms preprocess, 182.8ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 208.2ms
# Speed: 0.0ms preprocess, 208.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 194.6ms
# Speed: 4.0ms preprocess, 194.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 219.8ms
# Speed: 5.5ms preprocess, 219.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 201.9ms
# Speed: 5.5ms preprocess, 201.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 2 trucks, 202.1ms
# Speed: 5.2ms preprocess, 202.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 181.2ms
# Speed: 0.9ms preprocess, 181.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 219.5ms
# Speed: 0.0ms preprocess, 219.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 233.6ms
# Speed: 4.8ms preprocess, 233.6ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 1 truck, 228.3ms
# Speed: 7.0ms preprocess, 228.3ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 2 trucks, 207.6ms
# Speed: 0.0ms preprocess, 207.6ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 2 trucks, 224.8ms
# Speed: 0.0ms preprocess, 224.8ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 2 trucks, 217.3ms
# Speed: 3.4ms preprocess, 217.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 2 trucks, 201.7ms
# Speed: 4.5ms preprocess, 201.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 216.8ms
# Speed: 6.5ms preprocess, 216.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 184.0ms
# Speed: 5.5ms preprocess, 184.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 194.6ms
# Speed: 0.0ms preprocess, 194.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 2 trucks, 193.0ms
# Speed: 0.0ms preprocess, 193.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 203.5ms
# Speed: 0.0ms preprocess, 203.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 204.5ms
# Speed: 5.8ms preprocess, 204.5ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 195.1ms
# Speed: 0.0ms preprocess, 195.1ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 176.3ms
# Speed: 4.7ms preprocess, 176.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 189.4ms
# Speed: 0.0ms preprocess, 189.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 187.0ms
# Speed: 0.0ms preprocess, 187.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 169.0ms
# Speed: 5.3ms preprocess, 169.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 163.5ms
# Speed: 0.0ms preprocess, 163.5ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 176.1ms
# Speed: 5.0ms preprocess, 176.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 194.8ms
# Speed: 5.7ms preprocess, 194.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 189.0ms
# Speed: 0.0ms preprocess, 189.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 207.0ms
# Speed: 0.0ms preprocess, 207.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 224.2ms
# Speed: 2.3ms preprocess, 224.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 236.8ms
# Speed: 1.1ms preprocess, 236.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 231.9ms
# Speed: 0.0ms preprocess, 231.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 210.9ms
# Speed: 7.5ms preprocess, 210.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 230.9ms
# Speed: 0.0ms preprocess, 230.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 226.3ms
# Speed: 0.0ms preprocess, 226.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 248.8ms
# Speed: 7.1ms preprocess, 248.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 193.4ms
# Speed: 0.0ms preprocess, 193.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 188.7ms
# Speed: 0.0ms preprocess, 188.7ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 219.2ms
# Speed: 5.1ms preprocess, 219.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 219.6ms
# Speed: 5.0ms preprocess, 219.6ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 248.2ms
# Speed: 7.4ms preprocess, 248.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 218.2ms
# Speed: 0.0ms preprocess, 218.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 motorcycle, 194.3ms
# Speed: 0.0ms preprocess, 194.3ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 228.1ms
# Speed: 0.6ms preprocess, 228.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 237.3ms
# Speed: 0.0ms preprocess, 237.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 206.9ms
# Speed: 0.0ms preprocess, 206.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 194.9ms
# Speed: 0.0ms preprocess, 194.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 262.5ms
# Speed: 5.7ms preprocess, 262.5ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 247.4ms
# Speed: 3.3ms preprocess, 247.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 242.7ms
# Speed: 0.0ms preprocess, 242.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 219.1ms
# Speed: 4.5ms preprocess, 219.1ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 207.2ms
# Speed: 0.0ms preprocess, 207.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 202.9ms
# Speed: 4.5ms preprocess, 202.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 216.8ms
# Speed: 1.0ms preprocess, 216.8ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 225.0ms
# Speed: 4.6ms preprocess, 225.0ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 220.3ms
# Speed: 4.0ms preprocess, 220.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 247.2ms
# Speed: 1.3ms preprocess, 247.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 204.7ms
# Speed: 5.0ms preprocess, 204.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 219.2ms
# Speed: 5.0ms preprocess, 219.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 205.1ms
# Speed: 7.0ms preprocess, 205.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 229.2ms
# Speed: 1.0ms preprocess, 229.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 262.1ms
# Speed: 5.0ms preprocess, 262.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 223.2ms
# Speed: 5.0ms preprocess, 223.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 239.1ms
# Speed: 3.5ms preprocess, 239.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 218.2ms
# Speed: 6.6ms preprocess, 218.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 motorcycle, 1 truck, 229.8ms
# Speed: 4.3ms preprocess, 229.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 motorcycle, 1 truck, 253.6ms
# Speed: 1.2ms preprocess, 253.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 248.3ms
# Speed: 5.4ms preprocess, 248.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 216.1ms
# Speed: 5.0ms preprocess, 216.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 72.2ms
# Speed: 0.0ms preprocess, 72.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 71.6ms
# Speed: 0.0ms preprocess, 71.6ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 73.0ms
# Speed: 0.0ms preprocess, 73.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 73.0ms
# Speed: 0.0ms preprocess, 73.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 72.1ms
# Speed: 0.0ms preprocess, 72.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 96.1ms
# Speed: 7.0ms preprocess, 96.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 66.4ms
# Speed: 0.0ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 72.8ms
# Speed: 0.0ms preprocess, 72.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 79.7ms
# Speed: 0.0ms preprocess, 79.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 1 traffic light, 84.7ms
# Speed: 0.0ms preprocess, 84.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 73.4ms
# Speed: 0.0ms preprocess, 73.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 79.9ms
# Speed: 0.0ms preprocess, 79.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 71.9ms
# Speed: 0.0ms preprocess, 71.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 72.4ms
# Speed: 0.0ms preprocess, 72.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 73.1ms
# Speed: 0.0ms preprocess, 73.1ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 72.9ms
# Speed: 0.0ms preprocess, 72.9ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 72.7ms
# Speed: 0.0ms preprocess, 72.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 72.7ms
# Speed: 0.0ms preprocess, 72.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 67.8ms
# Speed: 0.0ms preprocess, 67.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 71.7ms
# Speed: 3.0ms preprocess, 71.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 73.7ms
# Speed: 2.1ms preprocess, 73.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 65.4ms
# Speed: 0.0ms preprocess, 65.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 65.3ms
# Speed: 1.3ms preprocess, 65.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 68.5ms
# Speed: 2.0ms preprocess, 68.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 85.1ms
# Speed: 1.6ms preprocess, 85.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 2 motorcycles, 77.7ms
# Speed: 3.0ms preprocess, 77.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 2 motorcycles, 68.3ms
# Speed: 2.4ms preprocess, 68.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 2 motorcycles, 78.7ms
# Speed: 1.2ms preprocess, 78.7ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 motorcycle, 1 truck, 83.4ms
# Speed: 1.8ms preprocess, 83.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 motorcycle, 1 truck, 75.2ms
# Speed: 3.2ms preprocess, 75.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 1 truck, 73.2ms
# Speed: 0.0ms preprocess, 73.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 1 truck, 78.3ms
# Speed: 0.0ms preprocess, 78.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 1 truck, 79.3ms
# Speed: 0.0ms preprocess, 79.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 1 truck, 69.2ms
# Speed: 2.4ms preprocess, 69.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 1 truck, 73.9ms
# Speed: 3.2ms preprocess, 73.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 1 truck, 68.5ms
# Speed: 0.0ms preprocess, 68.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 1 truck, 65.0ms
# Speed: 0.0ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 1 truck, 61.6ms
# Speed: 1.1ms preprocess, 61.6ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 motorcycle, 60.6ms
# Speed: 2.7ms preprocess, 60.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 61.6ms
# Speed: 3.3ms preprocess, 61.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 54.8ms
# Speed: 1.5ms preprocess, 54.8ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 61.8ms
# Speed: 0.0ms preprocess, 61.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 2 motorcycles, 64.8ms
# Speed: 0.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 65.5ms
# Speed: 0.0ms preprocess, 65.5ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 65.4ms
# Speed: 0.0ms preprocess, 65.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 65.1ms
# Speed: 0.0ms preprocess, 65.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 motorcycle, 61.7ms
# Speed: 2.9ms preprocess, 61.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 motorcycle, 72.5ms
# Speed: 0.0ms preprocess, 72.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 motorcycle, 69.8ms
# Speed: 0.0ms preprocess, 69.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 motorcycle, 63.9ms
# Speed: 3.0ms preprocess, 63.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 74.4ms
# Speed: 2.1ms preprocess, 74.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 65.6ms
# Speed: 0.9ms preprocess, 65.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 75.9ms
# Speed: 0.8ms preprocess, 75.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 77.2ms
# Speed: 0.0ms preprocess, 77.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 66.1ms
# Speed: 2.1ms preprocess, 66.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 64.6ms
# Speed: 2.1ms preprocess, 64.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 79.9ms
# Speed: 1.8ms preprocess, 79.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 77.5ms
# Speed: 0.0ms preprocess, 77.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 1 truck, 68.5ms
# Speed: 0.0ms preprocess, 68.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 1 truck, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 1 truck, 58.9ms
# Speed: 0.0ms preprocess, 58.9ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 1 truck, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 1 truck, 84.1ms
# Speed: 0.0ms preprocess, 84.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 2 motorcycles, 1 truck, 67.2ms
# Speed: 0.0ms preprocess, 67.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 2 motorcycles, 1 bus, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 72.7ms
# Speed: 0.0ms preprocess, 72.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 60.5ms
# Speed: 0.0ms preprocess, 60.5ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 85.0ms
# Speed: 0.0ms preprocess, 85.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 66.8ms
# Speed: 0.0ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 84.2ms
# Speed: 0.0ms preprocess, 84.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 86.0ms
# Speed: 0.0ms preprocess, 86.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 66.5ms
# Speed: 0.0ms preprocess, 66.5ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 60.8ms
# Speed: 0.0ms preprocess, 60.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 66.3ms
# Speed: 0.0ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 72.2ms
# Speed: 0.0ms preprocess, 72.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 61.0ms
# Speed: 2.9ms preprocess, 61.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 motorcycle, 64.9ms
# Speed: 0.0ms preprocess, 64.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 motorcycle, 64.9ms
# Speed: 0.0ms preprocess, 64.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 motorcycle, 65.2ms
# Speed: 0.0ms preprocess, 65.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 motorcycle, 60.5ms
# Speed: 0.0ms preprocess, 60.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 motorcycle, 65.6ms
# Speed: 0.0ms preprocess, 65.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 71.2ms
# Speed: 0.0ms preprocess, 71.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 65.4ms
# Speed: 0.0ms preprocess, 65.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 71.2ms
# Speed: 0.0ms preprocess, 71.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 65.7ms
# Speed: 0.8ms preprocess, 65.7ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 68.2ms
# Speed: 2.4ms preprocess, 68.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 65.4ms
# Speed: 1.2ms preprocess, 65.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 67.2ms
# Speed: 0.0ms preprocess, 67.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 70.3ms
# Speed: 0.0ms preprocess, 70.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 78.2ms
# Speed: 0.0ms preprocess, 78.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 66.3ms
# Speed: 1.2ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 truck, 72.4ms
# Speed: 1.0ms preprocess, 72.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 75.2ms
# Speed: 0.0ms preprocess, 75.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 95.2ms
# Speed: 0.0ms preprocess, 95.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 71.7ms
# Speed: 3.1ms preprocess, 71.7ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 68.5ms
# Speed: 0.0ms preprocess, 68.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 64.7ms
# Speed: 2.0ms preprocess, 64.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 59.6ms
# Speed: 2.0ms preprocess, 59.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 59.7ms
# Speed: 2.0ms preprocess, 59.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 61.2ms
# Speed: 1.1ms preprocess, 61.2ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 72.6ms
# Speed: 2.6ms preprocess, 72.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 67.9ms
# Speed: 2.7ms preprocess, 67.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 62.1ms
# Speed: 2.8ms preprocess, 62.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 61.0ms
# Speed: 1.8ms preprocess, 61.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 68.3ms
# Speed: 0.0ms preprocess, 68.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 68.4ms
# Speed: 0.0ms preprocess, 68.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 67.7ms
# Speed: 0.0ms preprocess, 67.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 78.6ms
# Speed: 3.1ms preprocess, 78.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 64.9ms
# Speed: 0.0ms preprocess, 64.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 69.7ms
# Speed: 0.0ms preprocess, 69.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 62.9ms
# Speed: 3.4ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 63.6ms
# Speed: 0.0ms preprocess, 63.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 79.7ms
# Speed: 3.9ms preprocess, 79.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 71.2ms
# Speed: 0.0ms preprocess, 71.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 71.7ms
# Speed: 0.0ms preprocess, 71.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 72.6ms
# Speed: 0.0ms preprocess, 72.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 67.2ms
# Speed: 0.0ms preprocess, 67.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 78.9ms
# Speed: 0.0ms preprocess, 78.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 66.8ms
# Speed: 0.0ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 72.6ms
# Speed: 0.0ms preprocess, 72.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 72.5ms
# Speed: 0.0ms preprocess, 72.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 68.6ms
# Speed: 0.0ms preprocess, 68.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)

# %%
import os
import json
import csv

# Function to read a detection file and extract unique detections
def process_detection_file(file_path, unique_detections):
    with open(file_path, 'r') as file:
        data = json.load(file)
        for detection in data:
            key = (detection['track_id'], detection['name'])
            if key not in unique_detections:
                unique_detections[key] = detection

# Function to iterate through detection files in a folder
def process_detection_folder(folder_path, output_csv_path):
    unique_detections = {}
    for filename in os.listdir(folder_path):
        if filename.endswith('.txt'):
            file_path = os.path.join(folder_path, filename)
            process_detection_file(file_path, unique_detections)

    # Write unique detections to a CSV file
    with open(output_csv_path, 'w', newline='') as csvfile:
        fieldnames = ['track_id', 'name', 'class', 'confidence', 'box']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for detection in unique_detections.values():
            writer.writerow({
                'track_id': detection['track_id'],
                'name': detection['name'],
                'class': detection['class'],
                'confidence': detection['confidence'],
                'box': detection['box']
            })

# Replace 'detections_folder_path' and 'output_csv_path' with your actual folder and output file paths
detections_folder_path = 'detections'
output_csv_path = 'output.csv'

process_detection_folder(detections_folder_path, output_csv_path)

# %%
# view the csv file
import pandas as pd
df = pd.read_csv('output.csv', header=None)
df.head(10)
# Out:
#           0           1      2                   3  \
# 0  track_id        name  class          confidence
# 1         1         car      2  0.8836764693260193
# 2         2         car      2  0.8626297116279602
# 3         3         car      2  0.8476601839065552
# 4         4         car      2  0.8375164270401001
# 5         5         car      2  0.8217783570289612
# 6         6         car      2  0.7771808505058289
# 7         7         car      2  0.7722057700157166
# 8         8  motorcycle      3  0.6146885752677917
# 9         8      person      0  0.5050264596939087
#
#                                                    4
# 0                                                box
# 1  {'x1': 0.28173595428466797, 'y1': 0.2885417855...
# 2  {'x1': 0.5321219253540039, 'y1': 0.24044532280...
# 3  {'x1': 0.03666766166687012, 'y1': 0.5279136756...
# 4  {'x1': 0.29856979370117187, 'y1': 0.6793429552...
# 5  {'x1': 0.41848731994628907, 'y1': 0.3797470026...
# 6  {'x1': 0.2364187240600586, 'y1': 0.38601175944...
# 7  {'x1': 0.24698047637939452, 'y1': 0.2348987860...
# 8  {'x1': 0.7165263366699218, 'y1': 0.44739681095...
# 9  {'x1': 0.7372369384765625, 'y1': 0.39266019878...

# %%
import pandas as pd

# Replace 'input_csv_path' and 'output_csv_path' with your actual input and output file paths
input_csv_path = 'output.csv'
output_csv_path = 'output_2.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(input_csv_path)

# Remove rows where the value in the "name" column is "person" and fire hydrant
df_filtered = df[~df['name'].isin(['person', 'fire hydrant'])]

# Write the filtered DataFrame to a new CSV file
df_filtered.to_csv(output_csv_path, index=False)

# %%
df_filtered.head(10)

# unique in name
df_filtered['name'].unique()
# Out:
# array(['car', 'motorcycle', 'bus', 'truck', 'traffic light'], dtype=object)

# %%
# now you have to count car', 'motorcycle', 'bus', 'truck
# count the number of each class
# Replace 'input_csv_path' and 'output_csv_path' with your actual input and output file paths
input_csv_path = 'output_2.csv'
output_csv_path = 'output_3.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(input_csv_path)

# Group the DataFrame by the "name" column and count the number of rows in each group
df_grouped = df.groupby('name').size().reset_index(name='counts')

# Write the grouped DataFrame to a new CSV file
df_grouped.to_csv(output_csv_path, index=False)

df_grouped.head(10)
# Out:
#             name  counts
# 0            bus       7
# 1            car      82
# 2     motorcycle      36
# 3  traffic light       1
# 4          truck      26

# %%
import os
import json
import csv
from collections import defaultdict

def calculate_distance(x1, y1, x2, y2):
    # Calculate Euclidean distance
    return ((x2 - x1)**2 + (y2 - y1)**2)**0.5

def calculate_speed(distance, time_elapsed):
    # Calculate speed (distance / time)
    return distance / time_elapsed

def process_frame_data(frame_data, frame_number, object_speeds, csv_writer):
    for obj in frame_data:
        track_id = obj['track_id']
        class_name = obj['name']
        confidence = obj['confidence']
        box = obj['box']

        if class_name == "person":
            # Skip objects with the name "person"
            continue

        if (track_id, class_name) not in object_speeds:
            # If object not encountered before, store current frame data
            object_speeds[(track_id, class_name)] = {
                'box': box,
                'confidence': confidence,
                'frame': frame_number
            }
        else:
            # If object encountered before, calculate speed and write to CSV
            prev_frame_data = object_speeds[(track_id, class_name)]
            time_elapsed = frame_number - prev_frame_data['frame']
            distance = calculate_distance(prev_frame_data['box']['x1'],
                                          prev_frame_data['box']['y1'],
                                          box['x1'], box['y1'])
            speed = calculate_speed(distance, time_elapsed)

            # Write information to CSV
            csv_writer.writerow([class_name, track_id, speed])

            # Update the stored data for the object with current frame data
            object_speeds[(track_id, class_name)] = {
                'box': box,
                'confidence': confidence,
                'frame': frame_number
            }

# Initialize a dictionary to store object data and speeds
object_speeds = defaultdict(dict)

# Specify the CSV file path
csv_file_path = 'object_speeds.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write header to CSV
    csv_writer.writerow(['Name', 'ID', 'Speed'])

    # Iterate through each file in the 'detections' folder
    folder_path = 'detections'
    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):
            file_path = os.path.join(folder_path, filename)
            frame_number = int(filename.split('.')[0][5:])  # Extract frame number from filename
            with open(file_path, 'r') as file:
                frame_data = json.load(file)
                process_frame_data(frame_data, frame_number, object_speeds, csv_writer)

print(f"Data has been written to {csv_file_path}")
# Out:
# Data has been written to object_speeds.csv

# %%
# import os
# import json
# import csv
# from collections import defaultdict

# def calculate_distance(x1, y1, x2, y2):
#     # Calculate Euclidean distance
#     return ((x2 - x1)**2 + (y2 - y1)**2)**0.5

# def calculate_speed(distance, time_elapsed):
#     # Calculate speed (distance / time)
#     return distance / time_elapsed

# def process_frame_data(frame_data, frame_number, object_speeds, csv_writer):
#     for obj in frame_data:
#         track_id = obj['track_id']
#         class_name = obj['name']
#         confidence = obj['confidence']
#         box = obj['box']

#         if class_name == "person":
#             # Skip objects with the name "person"
#             continue

#         if (track_id, class_name) not in object_speeds:
#             # If object not encountered before, store current frame data
#             object_speeds[(track_id, class_name)] = {
#                 'box': box,
#                 'confidence': confidence,
#                 'frame': frame_number
#             }
#         else:
#             # If object encountered before, calculate speed and write to CSV
#             prev_frame_data = object_speeds[(track_id, class_name)]
#             time_elapsed = frame_number - prev_frame_data['frame']
#             distance = calculate_distance(prev_frame_data['box']['x1'],
#                                           prev_frame_data['box']['y1'],
#                                           box['x1'], box['y1'])
#             speed = calculate_speed(distance, time_elapsed)

#             # Write information to CSV
#             csv_writer.writerow([class_name, track_id, frame_number, speed])

#             # Update the stored data for the object with current frame data
#             object_speeds[(track_id, class_name)] = {
#                 'box': box,
#                 'confidence': confidence,
#                 'frame': frame_number
#             }

# # Initialize a dictionary to store object data and speeds
# object_speeds = defaultdict(dict)

# # Specify the CSV file path
# csv_file_path = 'object_speeds.csv'

# # Open the CSV file for writing
# with open(csv_file_path, 'w', newline='') as csv_file:
#     # Create a CSV writer
#     csv_writer = csv.writer(csv_file)

#     # Write header to CSV
#     csv_writer.writerow(['Name', 'ID', 'Frame', 'Speed'])

#     # Iterate through each file in the 'detections' folder
#     folder_path = 'detections'
#     for filename in os.listdir(folder_path):
#         if filename.endswith(".txt"):
#             file_path = os.path.join(folder_path, filename)
#             frame_number = int(filename.split('.')[0][5:])  # Extract frame number from filename
#             with open(file_path, 'r') as file:
#                 frame_data = json.load(file)
#                 process_frame_data(frame_data, frame_number, object_speeds, csv_writer)

# print(f"Data has been written to {csv_file_path}")

# %%
df3 = pd.read_csv('object_speeds.csv')
df3.head(10)
# Out:
#          Name  ID     Speed
# 0         car   1  0.000069
# 1         car   2  0.000125
# 2         car   3  0.000386
# 3         car   4  0.000345
# 4         car   5  0.000173
# 5         car   6  0.000376
# 6         car   7  0.000149
# 7  motorcycle   8  0.000629
# 8         car   1  0.002312
# 9         car   2  0.001287

# %%
# write speeds acc to id on the video
import cv2
import pandas as pd
import numpy as np

# Replace 'video_path' and 'speeds_csv_path' with your actual video and speeds CSV file paths
video_path = 'cropped_video.mp4'
speeds_csv_path = 'object_speeds.csv'

# Read the speeds CSV file into a DataFrame
df = pd.read_csv(speeds_csv_path)

# Initialize a video capture object
cap = cv2.VideoCapture(video_path)

# Initialize a list to store speeds
speeds = []

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Get the frame number
        frame_number = int(cap.get(cv2.CAP_PROP_POS_FRAMES))

        # Get the speeds for the current frame from the DataFrame
        frame_speeds = df[df['Frame'] == frame_number]

        # Loop through the detected objects in the current frame
        for index, row in frame_speeds.iterrows():
            # Extract the object ID and speed from the row
            obj_id = row['ID']
            speed = row['Speed']

            # Draw the object ID and speed on the frame
            cv2.putText(frame, f"ID: {obj_id}", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(frame, f"Speed: {speed:.2f} px/s", (50, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

            # Append the speed to the list
            speeds.append(speed)

        # Display the frame
        cv2.imshow("Frame", frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break
        
# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
